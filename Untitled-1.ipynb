# %%
name="Ayush"
Score=83
print(f"Hello {name}, your score is {Score}.")

# %%
city="Fatehpur"
print(city)

# %%
a=7
b=3.0
print(type(a))
print(type(b))

# %%
a="3.14"
b=float(a)
print(2*b)
print(type(b))
